# %% [markdown]
# <a href="https://colab.research.google.com/github/MunasheActuarial/Dissertation-Code/blob/main/Final_Code2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the Excel dataset
file_path = '/content/Simulated_Operational_Risk_Data...xlsx'
df = pd.read_excel(file_path)

# Encoding categorical variable"Resolved" to numerical
df['Resolved'] = df['Resolved'].replace({'Yes': 1, 'No': 2})

# Encoding categorical variable"Control_Weakness" to numerical
df['Control_Weakness'] = df['Control_Weakness'].replace({'Yes': 1, 'No': 2})

# Assign numerical symbols to "Business_Line" and "Sub_Category"(Encoding)
business_line_mapping = {business_line: i for i, business_line in enumerate(df['Business_Line'].unique())}
df['Business_Line_Encoded'] = df['Business_Line'].map(business_line_mapping)

sub_category_mapping = {sub_category: i for i, sub_category in enumerate(df['Sub_Category'].unique())}
df['Sub_Category_Encoded'] = df['Sub_Category'].map(sub_category_mapping)

# Quick look at the data
print("Shape of dataset:", df.shape)
print("Column names:", df.columns.tolist())
df.head()
# Out:
# Shape of dataset: (200, 18)
# Column names: ['Event_ID', 'Business_Line', 'Sub_Category', 'Loss_Amount', 'Event_Date', 'Discovery_Date', 'Resolved', 'Risk_Rating', 'Control_Weakness', 'Internal_fraud', 'External_fraud', 'Employ_PWS', 'Clients_PBP', 'Disaster', 'ICT_Failure', 'Execution_DP', 'Business_Line_Encoded', 'Sub_Category_Encoded']
# <ipython-input-1-8cfa25e2f057>:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Resolved'] = df['Resolved'].replace({'Yes': 1, 'No': 2})
# <ipython-input-1-8cfa25e2f057>:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Control_Weakness'] = df['Control_Weakness'].replace({'Yes': 1, 'No': 2})
#   Event_ID       Business_Line           Sub_Category  Loss_Amount Event_Date  \
# 0  EVT1000    Asset Management  Real Asset Management         6024 2022-05-10
# 1  EVT1001   Corporate Finance      Berue De Exchange        71904 2019-12-11
# 2  EVT1002  Commercial Banking          Micro-finance        26887 2015-01-03
# 3  EVT1003    Funeral Services       Funeral Services        24723 2015-08-10
# 4  EVT1004   Corporate Finance      Berue De Exchange        34374 2017-03-19
#
#   Discovery_Date  Resolved  Risk_Rating  Control_Weakness  Internal_fraud  \
# 0     2022-07-31         2            6                 2             619
# 1     2020-01-12         1            6                 1            2385
# 2     2015-03-24         2            3                 1            3400
# 3     2015-10-27         2            7                 1            3782
# 4     2017-04-13         1            3                 2            1058
#
#    External_fraud  Employ_PWS  Clients_PBP  Disaster  ICT_Failure  \
# 0            1240         309         1507       201           60
# 1           25168       16271        11717      7312          522
# 2            3455        5422         5124      1609          994
# 3            7391        6949         1247      1591          291
# 4           11962        4365         7043       850          133
#
#    Execution_DP  Business_Line_Encoded  Sub_Category_Encoded
# 0          2088                      0                     0
# 1          8529                      1                     1
# 2          6883                      2                     2
# 3          3472                      3                     3
# 4          8963                      1                     1

# %%
# prompt: Code for descriptive statistics of Loss_Amount, Internal_fraud, External_fraud,  and  Execution_DP

# Descriptive statistics for specified columns
descriptive_stats = df[['Loss_Amount', 'Internal_fraud', 'External_fraud', 'Execution_DP']].describe()
descriptive_stats
# Out:
#          Loss_Amount  Internal_fraud  External_fraud  Execution_DP
# count     200.000000      200.000000      200.000000    200.000000
# mean    33569.200000     4075.860000     7005.965000   8642.985000
# std     48621.220374     7510.160989    15474.797012  11581.508376
# min       706.000000       12.000000       34.000000     45.000000
# 25%      9036.000000      717.500000     1323.500000   1681.250000
# 50%     17256.000000     1855.500000     3076.000000   4449.500000
# 75%     40963.000000     4782.750000     7783.250000  10231.250000
# max    505809.000000    89260.000000   193290.000000  71386.000000

# %%
# prompt: Code for descriptive statistics of Employ_PWS, Clients_PBP,  Disaster, ICT_Failure

# Descriptive statistics for specified columns
descriptive_stats = df[['Employ_PWS', 'Clients_PBP', 'Disaster', 'ICT_Failure']].describe()
descriptive_stats
# Out:
#          Employ_PWS   Clients_PBP      Disaster   ICT_Failure
# count    200.000000    200.000000    200.000000    200.000000
# mean    5149.965000   5863.270000   1862.155000    969.000000
# std     7130.521757   9661.837417   2944.270479   1820.544603
# min        2.000000     24.000000     10.000000      1.000000
# 25%      991.250000    952.250000    335.000000    100.250000
# 50%     2436.500000   2584.000000    828.500000    370.500000
# 75%     5808.250000   7051.500000   2150.250000    996.000000
# max    44640.000000  89805.000000  28220.000000  18643.000000

# %%
# prompt: Code for Univariate Analysis

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Univariate Analysis for Numerical Columns
numerical_cols = ['Loss_Amount', 'Internal_fraud', 'External_fraud', 'Execution_DP', 'Employ_PWS', 'Clients_PBP', 'Disaster', 'ICT_Failure']

for col in numerical_cols:
  print(f"\nUnivariate Analysis for {col}:")
  print(df[col].describe())  # Descriptive statistics

  plt.figure(figsize=(8, 6))
  sns.histplot(df[col], kde=True) # Histogram with KDE
  plt.title(f'Distribution of {col}')
  plt.xlabel(col)
  plt.ylabel('Frequency')
  plt.show()

  plt.figure(figsize=(8, 6))
  sns.boxplot(y=df[col]) # Boxplot
  plt.title(f'Boxplot of {col}')
  plt.ylabel(col)
  plt.show()


# Univariate Analysis for Categorical Columns
categorical_cols = ['Resolved', 'Control_Weakness', 'Business_Line', 'Sub_Category']

for col in categorical_cols:
    print(f"\nUnivariate Analysis for {col}:")
    print(df[col].value_counts()) # Frequency counts

    plt.figure(figsize=(8, 6))
    df[col].value_counts().plot(kind='bar') # Bar plot of frequencies
    plt.title(f'Frequency Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Univariate Analysis for Loss_Amount:
# count       200.000000
# mean      33569.200000
# std       48621.220374
# min         706.000000
# 25%        9036.000000
# 50%       17256.000000
# 75%       40963.000000
# max      505809.000000
# Name: Loss_Amount, dtype: float64
# Univariate Analysis for Internal_fraud:
# count      200.000000
# mean      4075.860000
# std       7510.160989
# min         12.000000
# 25%        717.500000
# 50%       1855.500000
# 75%       4782.750000
# max      89260.000000
# Name: Internal_fraud, dtype: float64
# Univariate Analysis for External_fraud:
# count       200.000000
# mean       7005.965000
# std       15474.797012
# min          34.000000
# 25%        1323.500000
# 50%        3076.000000
# 75%        7783.250000
# max      193290.000000
# Name: External_fraud, dtype: float64
# Univariate Analysis for Execution_DP:
# count      200.000000
# mean      8642.985000
# std      11581.508376
# min         45.000000
# 25%       1681.250000
# 50%       4449.500000
# 75%      10231.250000
# max      71386.000000
# Name: Execution_DP, dtype: float64
# Univariate Analysis for Employ_PWS:
# count      200.000000
# mean      5149.965000
# std       7130.521757
# min          2.000000
# 25%        991.250000
# 50%       2436.500000
# 75%       5808.250000
# max      44640.000000
# Name: Employ_PWS, dtype: float64
# Univariate Analysis for Clients_PBP:
# count      200.000000
# mean      5863.270000
# std       9661.837417
# min         24.000000
# 25%        952.250000
# 50%       2584.000000
# 75%       7051.500000
# max      89805.000000
# Name: Clients_PBP, dtype: float64
# Univariate Analysis for Disaster:
# count      200.000000
# mean      1862.155000
# std       2944.270479
# min         10.000000
# 25%        335.000000
# 50%        828.500000
# 75%       2150.250000
# max      28220.000000
# Name: Disaster, dtype: float64
# Univariate Analysis for ICT_Failure:
# count      200.000000
# mean       969.000000
# std       1820.544603
# min          1.000000
# 25%        100.250000
# 50%        370.500000
# 75%        996.000000
# max      18643.000000
# Name: ICT_Failure, dtype: float64
# Univariate Analysis for Resolved:
# Resolved
# 2    101
# 1     99
# Name: count, dtype: int64
# Univariate Analysis for Control_Weakness:
# Control_Weakness
# 1    104
# 2     96
# Name: count, dtype: int64
# Univariate Analysis for Business_Line:
# Business_Line
# Commercial Banking    49
# Asset Management      30
# Insurance             29
# Investment banks      26
# Funeral Services      26
# Corporate Finance     20
# Pension Funds         20
# Name: count, dtype: int64
# Univariate Analysis for Sub_Category:
# Sub_Category
# Retail Banking                              36
# Funeral Services                            26
# Pension Funds                               20
# Micro-finance                               17
# Trading and Sales                           13
# Corporate Asset Management                  11
# Electronic Banking and Fintech Solutions    10
# Reinsurance                                  8
# Life Insurance                               8
# Public Asset Management                      8
# Real Asset Management                        7
# Micro-insurance                              7
# Berue De Exchange                            7
# General Insurance                            6
# Corporate Finance                            6
# International Banking                        6
# Investment Asset Management                  4
# Name: count, dtype: int64

# %%
# prompt: Code to analyze Loss_Amount with Business_Line

import matplotlib.pyplot as plt
import seaborn as sns # Import the seaborn library

# Bivariate analysis: Loss_Amount vs. Business_Line
plt.figure(figsize=(12, 6))
sns.boxplot(x='Business_Line', y='Loss_Amount', data=df)
plt.title('Loss Amount Distribution by Business Line')
plt.xlabel('Business Line')
plt.ylabel('Loss Amount')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

plt.figure(figsize=(12, 6))
sns.violinplot(x='Business_Line', y='Loss_Amount', data=df)
plt.title('Loss Amount Distribution by Business Line (Violin Plot)')
plt.xlabel('Business Line')
plt.ylabel('Loss Amount')
plt.xticks(rotation=45, ha='right')
plt.show()

# Calculate the mean loss amount for each business line
mean_loss_by_business_line = df.groupby('Business_Line')['Loss_Amount'].mean()
print("\nMean Loss Amount by Business Line:\n", mean_loss_by_business_line)

# Calculate other descriptive statistics for Loss Amount by Business Line
loss_stats_by_business_line = df.groupby('Business_Line')['Loss_Amount'].agg(['mean', 'median', 'std', 'min', 'max'])
print("\nDescriptive Statistics of Loss Amount by Business Line:\n", loss_stats_by_business_line)
# Out:
# Mean Loss Amount by Business Line:
#  Business_Line
# Asset Management      36168.866667
# Commercial Banking    44482.306122
# Corporate Finance     29465.900000
# Funeral Services      26157.769231
# Insurance             31128.482759
# Investment banks      23620.653846
# Pension Funds         33142.900000
# Name: Loss_Amount, dtype: float64
#
# Descriptive Statistics of Loss Amount by Business Line:
#                              mean   median           std   min     max
# Business_Line
# Asset Management    36168.866667  24620.5  36232.302870  4193  136234
# Commercial Banking  44482.306122  17947.0  77201.986107  1528  505809
# Corporate Finance   29465.900000  19750.5  25277.077891  4170  102601
# Funeral Services    26157.769231  18008.5  31451.492682  3451  151011
# Insurance           31128.482759  19030.0  36428.338106  1733  143753
# Investment banks    23620.653846  13369.5  23626.607162   706   96850
# Pension Funds       33142.900000  16407.5  50130.467377  1105  223271

# %%
# prompt: Code for Univariate Analysis of Business_Line

import matplotlib.pyplot as plt


# Univariate Analysis for Business_Line (Categorical)
print(f"\nUnivariate Analysis for Business_Line:")
print(df['Business_Line'].value_counts())  # Frequency counts

plt.figure(figsize=(10, 6))
df['Business_Line'].value_counts().plot(kind='bar')
plt.title('Frequency Distribution of Business_Line')
plt.xlabel('Business_Line')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.show()


plt.figure(figsize=(10, 6))
df['Business_Line'].value_counts(normalize=True).plot(kind='bar') # Normalized frequency
plt.title('Normalized Frequency Distribution of Business_Line')
plt.xlabel('Business_Line')
plt.ylabel('Proportion')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# Univariate Analysis for Business_Line:
# Business_Line
# Commercial Banking    49
# Asset Management      30
# Insurance             29
# Investment banks      26
# Funeral Services      26
# Corporate Finance     20
# Pension Funds         20
# Name: count, dtype: int64

# %%
# prompt: Code for analysis of categorical variables with Loss_Amount

import matplotlib.pyplot as plt


# Bivariate analysis: Loss_Amount vs. other categorical variables
categorical_cols = ['Resolved', 'Control_Weakness', 'Risk_Rating']

for col in categorical_cols:
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=col, y='Loss_Amount', data=df)
    plt.title(f'Loss Amount Distribution by {col}')
    plt.xlabel(col)
    plt.ylabel('Loss Amount')
    plt.xticks(rotation=45, ha='right')
    plt.show()

    plt.figure(figsize=(12, 6))
    sns.violinplot(x=col, y='Loss_Amount', data=df)
    plt.title(f'Loss Amount Distribution by {col} (Violin Plot)')
    plt.xlabel(col)
    plt.ylabel('Loss Amount')
    plt.xticks(rotation=45, ha='right')
    plt.show()

    # Calculate descriptive statistics for Loss Amount by each category
    loss_stats_by_category = df.groupby(col)['Loss_Amount'].agg(['mean', 'median', 'std', 'min', 'max'])
    print(f"\nDescriptive Statistics of Loss Amount by {col}:\n", loss_stats_by_category)
# Out:
# Descriptive Statistics of Loss Amount by Resolved:
#                    mean   median           std   min     max
# Resolved
# 1         37253.555556  22730.0  41787.270844  1105  223271
# 2         29957.801980  16397.0  54465.971739   706  505809
# Descriptive Statistics of Loss Amount by Control_Weakness:
#                            mean   median           std   min     max
# Control_Weakness
# 1                 31033.096154  13774.5  56307.834785   706  505809
# 2                 36316.645833  24954.0  38726.855484  1105  223271
# Descriptive Statistics of Loss Amount by Risk_Rating:
#                       mean   median            std   min     max
# Risk_Rating
# 1            43453.083333  28123.0   51258.517595  1882  223271
# 2            32624.375000  18517.0   47431.347950  2670  184569
# 3            36190.571429  28544.0   30461.088356  5587  126316
# 4            33990.000000  16083.0   43737.761343  6355  151011
# 5            50117.588235  17013.0  118581.246799  1733  505809
# 6            36193.681818  21711.5   36232.392965  4389  136234
# 7            21340.000000  15365.0   15852.863464  4564   54730
# 8            26029.083333  10765.5   30792.107619  1528  102601
# 9            22750.714286  12534.0   22306.609926  2228   74884
# 10           32876.823529  23042.0   32987.216890   706  112418

# %%
# prompt: Code for testing normality

from scipy.stats import shapiro, normaltest, anderson
from sklearn.preprocessing import PowerTransformer

# Normality Tests
def test_normality(data, column_name):
    """Tests the normality of a given column using Shapiro-Wilk, D'Agostino's K^2, and Anderson-Darling tests."""
    print(f"\nNormality Tests for {column_name}:")

    # Shapiro-Wilk Test
    stat, p = shapiro(data[column_name])
    print('Shapiro-Wilk Statistic=%.3f, p=%.3f' % (stat, p))
    alpha = 0.05
    if p > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
    else:
        print('Sample does not look Gaussian (reject H0)')

    # D'Agostino's K^2 Test
    stat, p = normaltest(data[column_name])
    print('D\'Agostino\'s K^2 Statistic=%.3f, p=%.3f' % (stat, p))
    alpha = 0.05
    if p > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
    else:
        print('Sample does not look Gaussian (reject H0)')

    # Anderson-Darling Test
    result = anderson(data[column_name])
    print('Anderson-Darling Statistic: %.3f' % result.statistic)
    p = 0  # Initialize p-value
    for i in range(len(result.critical_values)):
        sl, cv = result.significance_level[i], result.critical_values[i]
        if result.statistic < result.critical_values[i]:
            print(f'%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
        else:
          print(f'%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))

    # Apply Power Transformation if data is not normal
    alpha = 0.05
    stat, p = shapiro(data[column_name])
    if p <= alpha: # Apply transformation only if normality test fails
      print(f"Applying Power Transformer to {column_name}...")
      pt = PowerTransformer() # Yeo-Johnson by default
      data[column_name] = pt.fit_transform(data[[column_name]])

      print("After Power Transform:")
      stat, p = shapiro(data[column_name])
      print('Shapiro-Wilk Statistic=%.3f, p=%.3f' % (stat, p))
      if p > alpha:
        print('Transformed sample looks Gaussian (fail to reject H0)')
      else:
        print('Transformed sample does not look Gaussian (reject H0)')
    else:
      print(f"Data for {column_name} seems normal, no transformation needed.")

# Apply normality tests to numerical columns
numerical_cols = ['Loss_Amount', 'ICT_Failure', 'Employ_PWS', 'Clients_PBP', 'Disaster', 'Execution_DP'] # Add other numerical columns as needed.
for col in numerical_cols:
    test_normality(df, col)
# Out:
# Normality Tests for Loss_Amount:
# Shapiro-Wilk Statistic=0.551, p=0.000
# Sample does not look Gaussian (reject H0)
# D'Agostino's K^2 Statistic=259.218, p=0.000
# Sample does not look Gaussian (reject H0)
# Anderson-Darling Statistic: 20.943
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.644, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.901, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# Applying Power Transformer to Loss_Amount...
# After Power Transform:
# Shapiro-Wilk Statistic=0.997, p=0.982
# Transformed sample looks Gaussian (fail to reject H0)
#
# Normality Tests for ICT_Failure:
# Shapiro-Wilk Statistic=0.498, p=0.000
# Sample does not look Gaussian (reject H0)
# D'Agostino's K^2 Statistic=263.337, p=0.000
# Sample does not look Gaussian (reject H0)
# Anderson-Darling Statistic: 26.878
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.644, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.901, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# Applying Power Transformer to ICT_Failure...
# After Power Transform:
# Shapiro-Wilk Statistic=0.993, p=0.415
# Transformed sample looks Gaussian (fail to reject H0)
#
# Normality Tests for Employ_PWS:
# Shapiro-Wilk Statistic=0.672, p=0.000
# Sample does not look Gaussian (reject H0)
# D'Agostino's K^2 Statistic=124.529, p=0.000
# Sample does not look Gaussian (reject H0)
# Anderson-Darling Statistic: 22.014
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.644, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.901, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# Applying Power Transformer to Employ_PWS...
# After Power Transform:
# Shapiro-Wilk Statistic=0.994, p=0.563
# Transformed sample looks Gaussian (fail to reject H0)
#
# Normality Tests for Clients_PBP:
# Shapiro-Wilk Statistic=0.552, p=0.000
# Sample does not look Gaussian (reject H0)
# D'Agostino's K^2 Statistic=226.842, p=0.000
# Sample does not look Gaussian (reject H0)
# Anderson-Darling Statistic: 24.583
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.644, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.901, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# Applying Power Transformer to Clients_PBP...
# After Power Transform:
# Shapiro-Wilk Statistic=0.997, p=0.964
# Transformed sample looks Gaussian (fail to reject H0)
#
# Normality Tests for Disaster:
# Shapiro-Wilk Statistic=0.581, p=0.000
# Sample does not look Gaussian (reject H0)
# D'Agostino's K^2 Statistic=228.984, p=0.000
# Sample does not look Gaussian (reject H0)
# Anderson-Darling Statistic: 21.427
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.644, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.901, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# Applying Power Transformer to Disaster...
# After Power Transform:
# Shapiro-Wilk Statistic=0.992, p=0.396
# Transformed sample looks Gaussian (fail to reject H0)
#
# Normality Tests for Execution_DP:
# Shapiro-Wilk Statistic=0.683, p=0.000
# Sample does not look Gaussian (reject H0)
# D'Agostino's K^2 Statistic=132.757, p=0.000
# Sample does not look Gaussian (reject H0)
# Anderson-Darling Statistic: 19.465
# 15.000: 0.565, data does not look normal (reject H0)
# 10.000: 0.644, data does not look normal (reject H0)
# 5.000: 0.772, data does not look normal (reject H0)
# 2.500: 0.901, data does not look normal (reject H0)
# 1.000: 1.071, data does not look normal (reject H0)
# Applying Power Transformer to Execution_DP...
# After Power Transform:
# Shapiro-Wilk Statistic=0.995, p=0.787
# Transformed sample looks Gaussian (fail to reject H0)

# %%
# prompt: Code for feature ranking and correlation analysis

import matplotlib.pyplot as plt
import seaborn as sns # Import seaborn for heatmap

# Select only numerical features for correlation analysis
numerical_features = df.select_dtypes(include=['number']).columns.tolist()
numerical_features = [f for f in numerical_features if f not in ['Event_ID']]  # Exclude 'Event_ID'
correlation_matrix = df[numerical_features].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# Feature Ranking based on correlation with 'Loss_Amount'
correlation_with_loss = correlation_matrix['Loss_Amount'].abs().sort_values(ascending=False)
print("\nFeature Ranking based on absolute correlation with Loss_Amount:")
print(correlation_with_loss)
# Out:
# Feature Ranking based on absolute correlation with Loss_Amount:
# Loss_Amount              1.000000
# Execution_DP             0.851909
# Clients_PBP              0.839769
# Employ_PWS               0.811558
# Disaster                 0.794221
# ICT_Failure              0.696117
# Internal_fraud           0.598775
# External_fraud           0.519210
# Control_Weakness         0.163574
# Business_Line_Encoded    0.126130
# Risk_Rating              0.121647
# Resolved                 0.115428
# Sub_Category_Encoded     0.060300
# Name: Loss_Amount, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# Drop any rows with missing values
df.dropna(inplace=True)

# Defining the target variable in a column named Loss_Amount
target_col = 'Loss_Amount'
# Select only numerical features for scaling, excluding date and ID columns
numerical_features = df.select_dtypes(include=['number']).columns.tolist()
numerical_features = [f for f in numerical_features if f not in [target_col, 'Event_ID']]
X = df[numerical_features]
y = df[target_col]

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y.values, test_size=0.2, random_state=42
)

print("Training set shape:", X_train.shape)
print("Test set shape:", X_test.shape)
# Out:
# Training set shape: (160, 12)
# Test set shape: (40, 12)

# %%
import tensorflow as tf
from tensorflow.keras import layers

# Define a simple neural network model for regression
def create_bnn_model(input_dim):
    model = tf.keras.Sequential([
        layers.InputLayer(input_shape=(input_dim,)),
        layers.Dense(16, activation='relu'),
        layers.Dense(16, activation='relu'),
        layers.Dense(1)  # Output: Operational risk loss
    ])
    return model

input_dim = X_train.shape[1]
model = create_bnn_model(input_dim)
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 497 (1.94 KB)
#  Trainable params: 497 (1.94 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import numpy as np

# Log-prior: Assume standard Gaussian prior over weights
def log_prior(theta):
    return -0.5 * np.sum(theta**2)

# Log-likelihood: Assuming Gaussian likelihood for regression
def log_likelihood(theta, X, y):
    preds = X @ theta
    residual = y - preds
    return -0.5 * np.sum(residual ** 2)

# Full log-posterior
def log_posterior(theta, X, y):
    return log_prior(theta) + log_likelihood(theta, X, y)

# Gradient of log-posterior (used in leapfrog)
def grad_log_posterior(theta, X, y):
    preds = X @ theta
    grad_likelihood = X.T @ (y - preds)
    grad_prior = -theta
    return grad_likelihood + grad_prior

# Leapfrog integrator
def leapfrog(theta, r, step_size, num_steps, X, y):
    theta_new = theta.copy()
    r_new = r.copy()

    r_new += 0.5 * step_size * grad_log_posterior(theta_new, X, y)
    for _ in range(num_steps - 1):
        theta_new += step_size * r_new
        r_new += step_size * grad_log_posterior(theta_new, X, y)
    theta_new += step_size * r_new
    r_new += 0.5 * step_size * grad_log_posterior(theta_new, X, y)
    return theta_new, r_new

# Basic HMC Sampler
def hmc_sampler(
    initial_theta, X, y, num_samples=500, step_size=0.01, num_steps=20, mass=1.0
):
    samples = []
    theta = initial_theta.copy()
    dim = len(initial_theta)

    for i in range(num_samples):
        r0 = np.random.normal(0, np.sqrt(mass), size=dim)
        theta_prop, r_prop = leapfrog(theta, r0, step_size, num_steps, X, y)

        # Compute energies
        current_U = -log_posterior(theta, X, y)
        current_K = 0.5 * np.sum(r0**2)

        proposed_U = -log_posterior(theta_prop, X, y)
        proposed_K = 0.5 * np.sum(r_prop**2)

        # Metropolis-Hastings acceptance
        accept_prob = np.exp((current_U + current_K) - (proposed_U + proposed_K))
        if np.random.rand() < accept_prob:
            theta = theta_prop

        samples.append(theta.copy())

        if i % 50 == 0:
            print(f"Sample {i}, Acceptance Probability: {accept_prob:.3f}")

    return np.array(samples)

# %%
# Select small subset of weights (e.g., linear regression on first layer)
X_subset = X_train
y_subset = y_train

# Initialize parameters (weights) randomly
initial_theta = np.random.randn(X_subset.shape[1])

# Run HMC
samples_hmc = hmc_sampler(initial_theta, X_subset, y_subset, num_samples=1000)
# Out:
# Sample 0, Acceptance Probability: 11.373
# Sample 50, Acceptance Probability: 1.010
# Sample 100, Acceptance Probability: 1.003
# Sample 150, Acceptance Probability: 0.994
# Sample 200, Acceptance Probability: 1.024
# Sample 250, Acceptance Probability: 0.992
# Sample 300, Acceptance Probability: 1.010
# Sample 350, Acceptance Probability: 1.006
# Sample 400, Acceptance Probability: 0.990
# Sample 450, Acceptance Probability: 1.024
# Sample 500, Acceptance Probability: 0.993
# Sample 550, Acceptance Probability: 1.000
# Sample 600, Acceptance Probability: 0.987
# Sample 650, Acceptance Probability: 1.007
# Sample 700, Acceptance Probability: 0.991
# Sample 750, Acceptance Probability: 0.997
# Sample 800, Acceptance Probability: 1.011
# Sample 850, Acceptance Probability: 1.007
# Sample 900, Acceptance Probability: 1.029
# Sample 950, Acceptance Probability: 0.975

# %%
import tensorflow as tf

# Flatten model weights into a 1D vector
def flatten_weights(model):
    weights = model.get_weights()
    return np.concatenate([w.flatten() for w in weights])

# Unflatten a vector back into model weights (matching model structure)
def unflatten_weights(model, flat_weights):
    shapes = [w.shape for w in model.get_weights()]
    new_weights = []
    idx = 0
    for shape in shapes:
        size = np.prod(shape)
        new_weights.append(flat_weights[idx:idx+size].reshape(shape))
        idx += size
    return new_weights

# %%
# Log-likelihood for neural net: uses model predictions
def nn_log_likelihood(theta, model, X, y):
    model.set_weights(unflatten_weights(model, theta))
    preds = model.predict(X, verbose=0).flatten()
    return -0.5 * np.sum((y - preds)**2)

# Gradient via backpropagation using TensorFlow
def nn_grad_log_likelihood(theta, model, X, y):
    model.set_weights(unflatten_weights(model, theta))

    with tf.GradientTape() as tape:
        inputs = tf.convert_to_tensor(X, dtype=tf.float32)
        targets = tf.convert_to_tensor(y, dtype=tf.float32)
        preds = tf.squeeze(model(inputs, training=False))
        loss = tf.reduce_mean((targets - preds)**2)

    grads = tape.gradient(loss, model.trainable_variables)
    grads = [g.numpy().flatten() for g in grads]
    grads = np.concatenate(grads)
    return -grads  # negative for log-likelihood gradient

# %%
# Setup
bnn_model = create_bnn_model(X_train.shape[1])
theta0 = flatten_weights(bnn_model)

# New versions for HMC using NN
def nn_log_posterior(theta, model, X, y):
    return -0.5 * np.sum(theta**2) + nn_log_likelihood(theta, model, X, y)

def nn_grad_log_posterior(theta, model, X, y):
    return -theta + nn_grad_log_likelihood(theta, model, X, y)

# Leapfrog for neural nets
def leapfrog_nn(theta, r, step_size, num_steps, model, X, y):
    theta_new = theta.copy()
    r_new = r.copy()

    r_new += 0.5 * step_size * nn_grad_log_posterior(theta_new, model, X, y)
    for _ in range(num_steps - 1):
        theta_new += step_size * r_new
        r_new += step_size * nn_grad_log_posterior(theta_new, model, X, y)
    theta_new += step_size * r_new
    r_new += 0.5 * step_size * nn_grad_log_posterior(theta_new, model, X, y)
    return theta_new, r_new

# Full HMC sampler for BNN
def hmc_bnn_sampler(initial_theta, model, X, y, num_samples=300, step_size=0.01, num_steps=15):
    samples = []
    theta = initial_theta.copy()
    dim = len(initial_theta)

    for i in range(num_samples):
        r0 = np.random.normal(0, 1, size=dim)
        theta_prop, r_prop = leapfrog_nn(theta, r0, step_size, num_steps, model, X, y)

        # Compute energy terms
        current_U = -nn_log_posterior(theta, model, X, y)
        current_K = 0.5 * np.sum(r0**2)
        proposed_U = -nn_log_posterior(theta_prop, model, X, y)
        proposed_K = 0.5 * np.sum(r_prop**2)

        # Metropolis acceptance
        accept_prob = np.exp((current_U + current_K) - (proposed_U + proposed_K))
        if np.random.rand() < accept_prob:
            theta = theta_prop

        samples.append(theta.copy())
        if i % 50 == 0:
            print(f"HMC Sample {i} | Acceptance Prob: {accept_prob:.3f}")

    return np.array(samples)

# %%
theta_init = flatten_weights(bnn_model)
samples = hmc_bnn_sampler(theta_init, bnn_model, X_train, y_train, num_samples=500)
# Out:
# HMC Sample 0 | Acceptance Prob: 0.000
# HMC Sample 50 | Acceptance Prob: 0.000
# HMC Sample 100 | Acceptance Prob: 0.000
# HMC Sample 150 | Acceptance Prob: 0.000
# HMC Sample 200 | Acceptance Prob: 0.000
# HMC Sample 250 | Acceptance Prob: 0.000
# HMC Sample 300 | Acceptance Prob: 0.000
# HMC Sample 350 | Acceptance Prob: 0.000
# HMC Sample 400 | Acceptance Prob: 0.000
# HMC Sample 450 | Acceptance Prob: 0.000

# %%
import numpy as np

def sghmc_sampler(
    initial_theta, model, X, y, batch_size=64,
    num_samples=300, step_size=0.01, alpha=0.01, beta=0.01, noise_std=0.01
):
    theta = initial_theta.copy()
    dim = len(initial_theta)
    samples = []

    # Velocity initialization
    velocity = np.zeros(dim)

    for i in range(num_samples):
        # Sample a minibatch
        indices = np.random.choice(len(X), size=batch_size, replace=False)
        X_batch = X[indices]
        y_batch = y[indices]

        # Compute stochastic gradient of log-posterior
        grad = nn_grad_log_posterior(theta, model, X_batch, y_batch)

        # Inject noise and friction (SGHMC core step)
        noise = np.random.normal(0, noise_std, size=dim)
        velocity = (1 - alpha) * velocity + step_size * grad + np.sqrt(2 * beta * step_size) * noise
        theta += velocity

        samples.append(theta.copy())

        if i % 50 == 0:
            print(f"SGHMC Sample {i}")

    return np.array(samples)

# %%
# Start from the same model
theta_init_sghmc = flatten_weights(bnn_model)

# Run SGHMC
samples_sghmc = sghmc_sampler(theta_init_sghmc, bnn_model, X_train, y_train, num_samples=500)
# Out:
# SGHMC Sample 0
# SGHMC Sample 50
# SGHMC Sample 100
# SGHMC Sample 150
# SGHMC Sample 200
# SGHMC Sample 250
# SGHMC Sample 300
# SGHMC Sample 350
# SGHMC Sample 400
# SGHMC Sample 450

# %%
def predict_from_samples(samples, model, X):
    preds = []
    for i, theta in enumerate(samples):
        model.set_weights(unflatten_weights(model, theta))
        pred = model.predict(X, verbose=0).flatten()
        preds.append(pred)
    return np.array(preds)  # Shape: (n_samples, n_points)

# %%
# HMC Predictions
preds_hmc = predict_from_samples(samples[:100], bnn_model, X_test)
mean_hmc = np.mean(preds_hmc, axis=0)
std_hmc = np.std(preds_hmc, axis=0)

# SGHMC Predictions
preds_sghmc = predict_from_samples(samples_sghmc[:100], bnn_model, X_test)
mean_sghmc = np.mean(preds_sghmc, axis=0)
std_sghmc = np.std(preds_sghmc, axis=0)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))

# HMC
plt.subplot(1, 2, 1)
plt.title("HMC Posterior Predictive")
plt.plot(y_test, label='True', color='black')
plt.plot(mean_hmc, label='Mean Prediction', color='blue')
plt.fill_between(range(len(mean_hmc)), mean_hmc - std_hmc, mean_hmc + std_hmc, color='blue', alpha=0.3)
plt.legend()

# SGHMC
plt.subplot(1, 2, 2)
plt.title("SGHMC Posterior Predictive")
plt.plot(y_test, label='True', color='black')
plt.plot(mean_sghmc, label='Mean Prediction', color='green')
plt.fill_between(range(len(mean_sghmc)), mean_sghmc - std_sghmc, mean_sghmc + std_sghmc, color='green', alpha=0.3)
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Linear regression model: y = Xw + noise
def linear_model(X, theta):
    return X @ theta

# %%
#Log Posterior and Gradient
def log_posterior(theta, X, y):
    pred = linear_model(X, theta)
    log_likelihood = -0.5 * np.sum((y - pred) ** 2)
    log_prior = -0.5 * np.sum(theta ** 2)
    return log_likelihood + log_prior

def grad_log_posterior(theta, X, y):
    pred = linear_model(X, theta)
    grad = X.T @ (y - pred) - theta
    return grad

# %%
#Utility: Leapfrog Step
def leapfrog(theta, r, step_size, X, y):
    r_half = r + 0.5 * step_size * grad_log_posterior(theta, X, y)
    theta_new = theta + step_size * r_half
    r_new = r_half + 0.5 * step_size * grad_log_posterior(theta_new, X, y)
    return theta_new, r_new

# %%
#NUTS Core Logic
def nuts_sampler(theta0, X, y, num_samples=5000, step_size=0.1, max_depth=5):
    D = len(theta0)
    samples = []
    theta = theta0.copy()

    def kinetic_energy(r): return 0.5 * np.sum(r ** 2)
    def h(theta, r): return -log_posterior(theta, X, y) + kinetic_energy(r)

    for i in range(num_samples):
        r0 = np.random.randn(D)
        joint0 = h(theta, r0)
        u = np.random.uniform(0, np.exp(-joint0))

        theta_minus = theta.copy()
        theta_plus = theta.copy()
        r_minus = r0.copy()
        r_plus = r0.copy()
        theta_candidate = theta.copy()
        depth = 0
        n = 1

        while depth < max_depth:
            direction = np.random.choice([-1, 1])
            if direction == -1:
                theta_minus, r_minus, _, _, theta_new, n_new, _ = build_tree(
                    theta_minus, r_minus, u, direction, depth, step_size, theta, r0, X, y
                )
            else:
                _, _, theta_plus, r_plus, theta_new, n_new, _ = build_tree(
                    theta_plus, r_plus, u, direction, depth, step_size, theta, r0, X, y
                )
            if np.random.rand() < n_new / max(n + n_new, 1):
                theta_candidate = theta_new
            n += n_new
            depth += 1
        theta = theta_candidate
        samples.append(theta.copy())
        if i % 50 == 0:
            print(f"NUTS Sample {i}")
    return np.array(samples)

# %%
def build_tree(theta, r, u, direction, depth, step_size, theta0, r0, X, y):
    if depth == 0:
        theta_prime, r_prime = leapfrog(theta, r, direction * step_size, X, y)
        joint = -log_posterior(theta_prime, X, y) + 0.5 * np.sum(r_prime ** 2)
        n_prime = int(u < np.exp(-joint))
        s_prime = int(u < np.exp(100 - joint))  # stay condition
        return theta_prime, r_prime, theta_prime, r_prime, theta_prime, n_prime, s_prime
    else:
        theta_m, r_m, theta_p, r_p, theta_prime, n_prime, s_prime = build_tree(
            theta, r, u, direction, depth - 1, step_size, theta0, r0, X, y
        )
        if s_prime == 1:
            if direction == -1:
                theta_m, r_m, _, _, theta_prime2, n_prime2, s_prime2 = build_tree(
                    theta_m, r_m, u, direction, depth - 1, step_size, theta0, r0, X, y
                )
            else:
                _, _, theta_p, r_p, theta_prime2, n_prime2, s_prime2 = build_tree(
                    theta_p, r_p, u, direction, depth - 1, step_size, theta0, r0, X, y
                )
            if np.random.rand() < n_prime2 / max(n_prime + n_prime2, 1):
                theta_prime = theta_prime2
            n_prime += n_prime2
            s_prime = s_prime and s_prime2
        return theta_m, r_m, theta_p, r_p, theta_prime, n_prime, s_prime

# %%
# For demo purposes, use small input
X_demo = X_train[:, :3]
y_demo = y_train
theta0 = np.zeros(X_demo.shape[1])

samples_nuts = nuts_sampler(theta0, X_demo, y_demo, num_samples=500)
# Out:
# NUTS Sample 0
# NUTS Sample 50
# NUTS Sample 100
# NUTS Sample 150
# NUTS Sample 200
# NUTS Sample 250
# NUTS Sample 300
# NUTS Sample 350
# NUTS Sample 400
# NUTS Sample 450

# %%
# Use mean of NUTS samples to make predictions
theta_nuts_mean = np.mean(samples_nuts, axis=0)

# Use the same features we trained on
X_test_demo = X_test[:, :3]

# Predictive mean
y_pred_nuts = X_test_demo @ theta_nuts_mean

# %%
plt.figure(figsize=(12, 6))

plt.plot(y_test[:40], label="True", color="black", linewidth=2) # Changed to 40
plt.plot(mean_hmc[:40], label="HMC", color="blue", linestyle="--") # Changed to 40
plt.plot(mean_sghmc[:40], label="SGHMC", color="green", linestyle="--") # Changed to 40
plt.plot(y_pred_nuts[:40], label="NUTS (Linear)", color="red", linestyle="--") # Changed to 40

plt.fill_between(range(40), mean_hmc[:40] - std_hmc[:40], mean_hmc[:40] + std_hmc[:40], alpha=0.2, color="blue") # Changed to 40
plt.fill_between(range(40), mean_sghmc[:40] - std_sghmc[:40], mean_sghmc[:40] + std_sghmc[:40], alpha=0.2, color="green") # Changed to 40


plt.title("Posterior Predictive Comparison (First 50 test points)")
plt.xlabel("Test Point Index")
plt.ylabel("Loss Amount Prediction")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def magnetic_leapfrog(theta, r, step_size, X, y, B):
    # Step 1: Rotate momentum due to magnetic field
    r = r + 0.5 * step_size * grad_log_posterior(theta, X, y)
    r = r + step_size * (B @ r)

    # Step 2: Update position
    theta = theta + step_size * r

    # Step 3: Apply magnetic field again
    r = r + step_size * (B @ r)
    r = r + 0.5 * step_size * grad_log_posterior(theta, X, y)

    return theta, r

# %%
def mhmc_sampler(theta0, X, y, num_samples=5000, step_size=0.05, num_steps=20):
    D = len(theta0)
    samples = []
    theta = theta0.copy()

    # Define a skew-symmetric matrix B to simulate the magnetic field
    B = np.zeros((D, D))
    for i in range(D - 1):
        B[i, i+1] = 1
        B[i+1, i] = -1

    for i in range(num_samples):
        r0 = np.random.randn(D)
        current_theta = theta.copy()
        current_r = r0.copy()

        # Simulate dynamics
        theta_new, r_new = current_theta.copy(), current_r.copy()
        for _ in range(num_steps):
            theta_new, r_new = magnetic_leapfrog(theta_new, r_new, step_size, X, y, B)

        # Compute energies
        current_U = -log_posterior(current_theta, X, y)
        current_K = 0.5 * np.sum(current_r ** 2)
        proposed_U = -log_posterior(theta_new, X, y)
        proposed_K = 0.5 * np.sum(r_new ** 2)

        accept_prob = np.exp(current_U - proposed_U + current_K - proposed_K)
        if np.random.rand() < accept_prob:
            theta = theta_new

        samples.append(theta.copy())
        if i % 50 == 0:
            print(f"MHMC Sample {i}")
    return np.array(samples)

# %%
# Smaller feature subset to keep computation light
X_demo = X_train[:, :3]
y_demo = y_train
theta0 = np.zeros(X_demo.shape[1])

samples_mhmc = mhmc_sampler(theta0, X_demo, y_demo, num_samples=500)
# Out:
# MHMC Sample 0
# MHMC Sample 50
# MHMC Sample 100
# MHMC Sample 150
# MHMC Sample 200
# MHMC Sample 250
# MHMC Sample 300
# MHMC Sample 350
# MHMC Sample 400
# MHMC Sample 450

# %%
theta_mhmc_mean = np.mean(samples_mhmc, axis=0)
X_test_demo = X_test[:, :3]
y_pred_mhmc = X_test_demo @ theta_mhmc_mean

# %%
plt.figure(figsize=(12, 6))

plt.plot(y_test[:50], label="True", color="black", linewidth=2)
plt.plot(mean_hmc[:50], label="HMC", color="blue", linestyle="--")
plt.plot(mean_sghmc[:50], label="SGHMC", color="green", linestyle="--")
plt.plot(y_pred_nuts[:50], label="NUTS", color="red", linestyle="--")
plt.plot(y_pred_mhmc[:50], label="MHMC", color="purple", linestyle="--")

plt.title("Posterior Predictive Comparison (First 50 test points)")
plt.xlabel("Test Index")
plt.ylabel("Loss Amount Prediction")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def ahmc_sampler(theta0, X, y, num_samples=5000, step_size=0.01, num_steps=30):
    D = len(theta0)
    samples = []
    theta = theta0.copy()

    # Define leapfrog_antithetic (assuming it's similar to leapfrog)
    def leapfrog_antithetic(theta, r, step_size, X, y, num_steps):
        """
        Leapfrog integration with antithetic sampling.

        This function should perform leapfrog integration, but
        it likely needs modifications for antithetic behavior.

        (This is a placeholder, adapt as needed based on your
         actual leapfrog implementation.)
        """
        for _ in range(num_steps):
            r_half = r + 0.5 * step_size * grad_log_posterior(theta, X, y)
            theta = theta + step_size * r_half
            r = r_half + 0.5 * step_size * grad_log_posterior(theta, X, y)
        return theta, r  # Return updated theta and momentum

    for i in range(num_samples // 2):
        r0 = np.random.randn(D)
        theta_new, r_new = leapfrog_antithetic(theta, r0, step_size, X, y, num_steps)

        # Compute energies
        current_U = -log_posterior(theta, X, y)
        current_K = 0.5 * np.sum(r0 ** 2)
        proposed_U = -log_posterior(theta_new, X, y)
        proposed_K = 0.5 * np.sum(r_new ** 2)

        accept_prob = np.exp(current_U - proposed_U + current_K - proposed_K)
        if np.random.rand() < accept_prob:
            theta = theta_new

        # Save both θ and its antithetic counterpart
        samples.append(theta.copy())

        # Antithetic sample
        r_antithetic = -r0
        theta_anti, _ = leapfrog_antithetic(theta, r_antithetic, step_size, X, y, num_steps)
        samples.append(theta_anti.copy())

        if i % 50 == 0:
            print(f"A-HMC Sample {2*i}/{num_samples}")
    return np.array(samples)

# %%
# Use same 3-feature subset as before
X_demo = X_train[:, :3]
y_demo = y_train
theta0 = np.zeros(X_demo.shape[1])

samples_ahmc = ahmc_sampler(theta0, X_demo, y_demo, num_samples=500)
# Out:
# A-HMC Sample 0/500
# A-HMC Sample 100/500
# A-HMC Sample 200/500
# A-HMC Sample 300/500
# A-HMC Sample 400/500

# %%
theta_ahmc_mean = np.mean(samples_ahmc, axis=0)
y_pred_ahmc = X_test_demo @ theta_ahmc_mean

# %%
plt.figure(figsize=(12, 6))

plt.plot(y_test[:50], label="True", color="black", linewidth=2)
plt.plot(mean_hmc[:50], label="HMC", color="blue", linestyle="--")
plt.plot(mean_sghmc[:50], label="SGHMC", color="green", linestyle="--")
plt.plot(y_pred_nuts[:50], label="NUTS", color="red", linestyle="--")
plt.plot(y_pred_mhmc[:50], label="MHMC", color="purple", linestyle="--")
plt.plot(y_pred_ahmc[:50], label="A-HMC", color="orange", linestyle="--")

plt.title("Posterior Predictive Comparison (First 50 test points)")
plt.xlabel("Test Index")
plt.ylabel("Loss Amount Prediction")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def s2hmc_leapfrog(theta, r, step_size, X, y):
    # Use fourth-order integrator constants
    c1 = 0.5153528374311229364
    c2 = -0.085782019412973646
    d1 = 0.1344961992774310892
    d2 = -0.2248198030794208058

    # 4th-order symplectic integrator
    def step(theta, r, c, d):
        r -= c * step_size * grad_log_posterior(theta, X, y)
        theta += d * step_size * r
        return theta, r

    theta, r = step(theta, r, c1, d1)
    theta, r = step(theta, r, c2, d2)
    theta, r = step(theta, r, c2, d1)
    theta, r = step(theta, r, c1, d1)

    return theta, r

# %%
def s2hmc_sampler(theta0, X, y, num_samples=5000, step_size=0.05, num_steps=20):
    D = len(theta0)
    samples = []
    theta = theta0.copy()

    for i in range(num_samples):
        r0 = np.random.randn(D)
        current_theta = theta.copy()
        current_r = r0.copy()

        # Simulate dynamics with shadow integrator
        theta_new, r_new = current_theta.copy(), current_r.copy()
        for _ in range(num_steps):
            theta_new, r_new = s2hmc_leapfrog(theta_new, r_new, step_size, X, y)

        # Compute energies
        current_U = -log_posterior(current_theta, X, y)
        current_K = 0.5 * np.sum(current_r ** 2)
        proposed_U = -log_posterior(theta_new, X, y)
        proposed_K = 0.5 * np.sum(r_new ** 2)

        accept_prob = np.exp(current_U - proposed_U + current_K - proposed_K)
        if np.random.rand() < accept_prob:
            theta = theta_new

        samples.append(theta.copy())
        if i % 50 == 0:
            print(f"S2HMC Sample {i}")
    return np.array(samples)

# %%
theta0 = np.zeros(X_demo.shape[1])
samples_s2hmc = s2hmc_sampler(theta0, X_demo, y_demo, num_samples=500)
# Out:
# S2HMC Sample 0
# S2HMC Sample 50
# S2HMC Sample 100
# S2HMC Sample 150
# S2HMC Sample 200
# S2HMC Sample 250
# S2HMC Sample 300
# S2HMC Sample 350
# S2HMC Sample 400
# S2HMC Sample 450

# %%
theta_s2hmc_mean = np.mean(samples_s2hmc, axis=0)
y_pred_s2hmc = X_test_demo @ theta_s2hmc_mean

# %%
plt.figure(figsize=(12, 6))

plt.plot(y_test[:50], label="True", color="black", linewidth=2)
plt.plot(mean_hmc[:50], label="HMC", color="blue", linestyle="--")
plt.plot(mean_sghmc[:50], label="SGHMC", color="green", linestyle="--")
plt.plot(y_pred_nuts[:50], label="NUTS", color="red", linestyle="--")
plt.plot(y_pred_mhmc[:50], label="MHMC", color="purple", linestyle="--")
plt.plot(y_pred_ahmc[:50], label="A-HMC", color="orange", linestyle="--")
plt.plot(y_pred_s2hmc[:50], label="S2HMC", color="brown", linestyle="--")

plt.title("Posterior Predictive Comparison (First 50 test points)")
plt.xlabel("Test Index")
plt.ylabel("Loss Amount Prediction")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    # Avoid division by zero
    y_true = np.where(y_true == 0, 1e-10, y_true)  # Replace zeros with a small value to avoid division by zero
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Assuming y_test, mean_hmc, mean_sghmc, y_pred_nuts, y_pred_mhmc, y_pred_ahmc, y_pred_s2hmc are already defined

methods = {
    "HMC": mean_hmc,
    "SGHMC": mean_sghmc,
    "NUTS": y_pred_nuts,
    "MHMC": y_pred_mhmc,
    "A-HMC": y_pred_ahmc,
    "S2HMC": y_pred_s2hmc,
}

results = []
for method, preds in methods.items():
    # Handle NaN values in preds, but keep at least one element
    valid_preds = preds[~np.isnan(preds)]

    # If all predictions are NaN, skip this method and record NaN for all metrics
    if len(valid_preds) == 0:
        results.append([method, np.nan, np.nan, np.nan, np.nan])
        continue

    # Slice y_test only to the length of valid predictions
    y_test_subset = y_test[:len(valid_preds)]

    rmse = np.sqrt(mean_squared_error(y_test_subset, valid_preds))
    mae = mean_absolute_error(y_test_subset, valid_preds)
    mape = mean_absolute_percentage_error(y_test_subset, valid_preds)
    r2 = r2_score(y_test_subset, valid_preds)
    results.append([method, rmse, mae, mape, r2])

results_df = pd.DataFrame(results, columns=["Method", "RMSE", "MAE", "MAPE", "R2"])
results_df
# Out:
#   Method      RMSE       MAE        MAPE        R2
# 0    HMC  0.583219  0.460158   71.411574  0.713049
# 1  SGHMC  0.676792  0.570848   68.229914  0.613583
# 2   NUTS  1.056530  0.914252  108.769860  0.058309
# 3   MHMC  1.056690  0.914665  108.284607  0.058022
# 4  A-HMC  1.056503  0.914360  108.576154  0.058356
# 5  S2HMC  1.088969  0.936690  100.000000 -0.000407

# %%
# prompt: Code to evaluate operational efficiency of each variant

import numpy as np
import pandas as pd

# Assuming results_df is already created as in the original code

# Calculate the operational efficiency for each method
# Operational Efficiency = 1 - (Loss Amount Prediction Error / Maximum Possible Loss Amount)

# Find the maximum loss amount in the test set
max_loss = np.max(y_test)

# Calculate the prediction error for each method (e.g., using RMSE)
for index, row in results_df.iterrows():
    method = row["Method"]
    rmse = row["RMSE"]

    # Normalize the error and subtract from 1
    operational_efficiency = 1 - (rmse / max_loss)

    # Store the efficiency
    results_df.loc[index, "Operational Efficiency"] = operational_efficiency

results_df
# Out:
#   Method      RMSE       MAE        MAPE        R2  Operational Efficiency
# 0    HMC  0.583219  0.460158   71.411574  0.713049                0.697099
# 1  SGHMC  0.676792  0.570848   68.229914  0.613583                0.648500
# 2   NUTS  1.056530  0.914252  108.769860  0.058309                0.451279
# 3   MHMC  1.056690  0.914665  108.284607  0.058022                0.451196
# 4  A-HMC  1.056503  0.914360  108.576154  0.058356                0.451293
# 5  S2HMC  1.088969  0.936690  100.000000 -0.000407                0.434431

# %%
# prompt: Code to add runtime of the remaining samplers

# ... (Your existing code) ...
import numpy as np
import time

# Function to time the execution of a sampler
def time_sampler(sampler_func, *args, **kwargs):
    start_time = time.time()
    samples = sampler_func(*args, **kwargs)
    end_time = time.time()
    return samples, end_time - start_time

# Time each sampler
hmc_samples, hmc_time = time_sampler(hmc_bnn_sampler, theta_init, bnn_model, X_train, y_train, num_samples=500)
sghmc_samples, sghmc_time = time_sampler(sghmc_sampler, theta_init_sghmc, bnn_model, X_train, y_train, num_samples=500)

nuts_samples, nuts_time = time_sampler(nuts_sampler, theta0, X_demo, y_demo, num_samples=500)
mhmc_samples, mhmc_time = time_sampler(mhmc_sampler, theta0, X_demo, y_demo, num_samples=500)
ahmc_samples, ahmc_time = time_sampler(ahmc_sampler, theta0, X_demo, y_demo, num_samples=500)
s2hmc_samples, s2hmc_time = time_sampler(s2hmc_sampler, theta0, X_demo, y_demo, num_samples=500)


print("HMC time:", hmc_time)
print("SGHMC time:", sghmc_time)
print("NUTS time:", nuts_time)
print("MHMC time:", mhmc_time)
print("AHMC time:", ahmc_time)
print("S2HMC time:", s2hmc_time)

# Create a dictionary to store the runtimes
sampler_runtimes = {
    "HMC": hmc_time,
    "SGHMC": sghmc_time,
    "NUTS": nuts_time,
    "MHMC": mhmc_time,
    "AHMC": ahmc_time,
    "S2HMC": s2hmc_time,
}

# Calculate the remaining runtime for each sampler (assuming a fixed number of samples)
total_samples = 500  # Or your desired total samples
remaining_runtimes = {}
for sampler, runtime in sampler_runtimes.items():
    remaining_runtimes[sampler] = runtime * (total_samples / 500 - 1)

# Print the results or save them to a DataFrame
print("\nEstimated Remaining Runtimes:")
for sampler, remaining_time in remaining_runtimes.items():
    print(f"{sampler}: {remaining_time:.2f} seconds")
# Out:
# HMC Sample 0 | Acceptance Prob: 0.000
# HMC Sample 50 | Acceptance Prob: 0.000
# HMC Sample 100 | Acceptance Prob: 0.000
# HMC Sample 150 | Acceptance Prob: 0.000
# HMC Sample 200 | Acceptance Prob: 0.000
# HMC Sample 250 | Acceptance Prob: 0.000
# HMC Sample 300 | Acceptance Prob: 0.000
# HMC Sample 350 | Acceptance Prob: 0.000
# HMC Sample 400 | Acceptance Prob: 0.000
# HMC Sample 450 | Acceptance Prob: 0.000
# SGHMC Sample 0
# SGHMC Sample 50
# SGHMC Sample 100
# SGHMC Sample 150
# SGHMC Sample 200
# SGHMC Sample 250
# SGHMC Sample 300
# SGHMC Sample 350
# SGHMC Sample 400
# SGHMC Sample 450
# NUTS Sample 0
# NUTS Sample 50
# NUTS Sample 100
# NUTS Sample 150
# NUTS Sample 200
# NUTS Sample 250
# NUTS Sample 300
# NUTS Sample 350
# NUTS Sample 400
# NUTS Sample 450
# MHMC Sample 0
# MHMC Sample 50
# MHMC Sample 100
# MHMC Sample 150
# MHMC Sample 200
# MHMC Sample 250
# MHMC Sample 300
# MHMC Sample 350
# MHMC Sample 400
# MHMC Sample 450
# A-HMC Sample 0/500
# A-HMC Sample 100/500
# A-HMC Sample 200/500
# A-HMC Sample 300/500
# A-HMC Sample 400/500
# S2HMC Sample 0
# S2HMC Sample 50
# S2HMC Sample 100
# S2HMC Sample 150
# S2HMC Sample 200
# S2HMC Sample 250
# S2HMC Sample 300
# S2HMC Sample 350
# S2HMC Sample 400
# S2HMC Sample 450
# HMC time: 220.0718355178833
# SGHMC time: 6.059785842895508
# NUTS time: 0.9379138946533203
# MHMC time: 0.2639772891998291
# AHMC time: 0.2649061679840088
# S2HMC time: 0.42717504501342773
#
# Estimated Remaining Runtimes:
# HMC: 0.00 seconds
# SGHMC: 0.00 seconds
# NUTS: 0.00 seconds
# MHMC: 0.00 seconds
# AHMC: 0.00 seconds
# S2HMC: 0.00 seconds

# %%
# prompt: Code to add trace plots of remailing samplers

import matplotlib.pyplot as plt
import numpy as np
# ... (Your existing code) ...

# Convergence diagnostics (example: trace plots)


def plot_traces(samples, param_indices=None, n_params_to_plot=5):
  if param_indices is None:
    param_indices = np.random.choice(samples.shape[1], size=min(n_params_to_plot, samples.shape[1]), replace=False)

  plt.figure(figsize=(10, 6))
  for i in param_indices:
      plt.plot(samples[:, i], label=f"Parameter {i}")
  plt.xlabel("Iteration")
  plt.ylabel("Parameter Value")
  plt.title("Trace Plot")
  plt.legend()
  plt.show()


plot_traces(hmc_samples)
plot_traces(sghmc_samples)
plot_traces(samples_nuts)
plot_traces(samples_mhmc)
plot_traces(samples_ahmc)
plot_traces(samples_s2hmc)

# %%
# prompt: Code to add runtime of the remaining samplers

import numpy as np
import time

# Function to time the execution of a sampler
def time_sampler(sampler_func, *args, **kwargs):
    start_time = time.time()
    samples = sampler_func(*args, **kwargs)
    end_time = time.time()
    return samples, end_time - start_time

# Evaluate runtime each  Hamiltonain Monte Carlo sampler
hmc_samples, hmc_time = time_sampler(hmc_bnn_sampler, theta_init, bnn_model, X_train, y_train, num_samples=500)
sghmc_samples, sghmc_time = time_sampler(sghmc_sampler, theta_init_sghmc, bnn_model, X_train, y_train, num_samples=500)

nuts_samples, nuts_time = time_sampler(nuts_sampler, theta0, X_demo, y_demo, num_samples=500)
mhmc_samples, mhmc_time = time_sampler(mhmc_sampler, theta0, X_demo, y_demo, num_samples=500)
ahmc_samples, ahmc_time = time_sampler(ahmc_sampler, theta0, X_demo, y_demo, num_samples=500)
s2hmc_samples, s2hmc_time = time_sampler(s2hmc_sampler, theta0, X_demo, y_demo, num_samples=500)


print("HMC time:", hmc_time)
print("SGHMC time:", sghmc_time)
print("NUTS time:", nuts_time)
print("MHMC time:", mhmc_time)
print("AHMC time:", ahmc_time)
print("S2HMC time:", s2hmc_time)

# Create a dictionary to store the runtimes
sampler_runtimes = {
    "HMC": hmc_time,
    "SGHMC": sghmc_time,
    "NUTS": nuts_time,
    "MHMC": mhmc_time,
    "AHMC": ahmc_time,
    "S2HMC": s2hmc_time,
}

# Calculate the remaining runtime for each sampler (assuming a fixed number of samples)
total_samples = 500  # Or your desired total samples
remaining_runtimes = {}
for sampler, runtime in sampler_runtimes.items():
    remaining_runtimes[sampler] = runtime * (total_samples / 500 - 1)

# Print the results or save them to a DataFrame
print("\nEstimated Remaining Runtimes:")
for sampler, remaining_time in remaining_runtimes.items():
    print(f"{sampler}: {remaining_time:.2f} seconds")
